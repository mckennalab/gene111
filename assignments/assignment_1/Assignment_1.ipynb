# %% [markdown]
# # Assignment 1
#
# Our goal today is to:
#
#  1. Learn about Jupyter notebooks
#  2. Learn how to use basic python command to manipulate strings

# %% [markdown]
# ### First a little about how Jupyter notebooks
#
# You can click the cell that this text is in to edit it. You'll see this is in something called 'Markdown'. This is a common text formatting language (not Python) used by blogs, Github, and other content management systems to neatly format text without a lot of window dressing. You can learn a bit more about markdown on its [original website](https://daringfireball.net/projects/markdown/syntax#list). For instance, when you click this cell you can see the header is set with 3 hashes (###). Try changing this to 2 hashes to see how the formatting changes. Jupyter allows you to specify a cell is markdown by choosing 'Markdown' from the format dropdown at the top of this window.
#
# ![Screen Shot 2021-05-09 at 9.14.40 PM.png](attachment:7d429530-506d-4621-98be-f8a260e04d34.png)
#
# Notebooks are supposed to be a place for interactive analysis and these Markdown cells give you a nice way to format ideas and provide context to your code. You can also stick in images like the one above to help explain what you're working on (or to hold notes for yourself).
#
# **You execute any cell by holding shift and hitting enter**. For Markdown that renders the cell into pretty text. For Python that runs the contents of that cell.

# %% [raw]
# This is a 'Raw' text cell. Again this cell formatting option is set by choosing 'Raw' at the top where we selected 'Markdown' for the cell above. Use cells like this for snippets you've captured from other tools you want to save, command you run on the command line, or other pieces of text that you'd like to show the user but not have Python worry about.

# %% [markdown]
# ### Into Python
#
# Now we're going to start using Python. We'll run through some quick examples on using strings as DNA sequences, comparing those sequences, some other common usages, etc. All of the homeworks in this class will build on that core knowledge, but there are a ton of other interactive Notebooks you can download to try out other aspects of Python:
#
# - [A really nice introduction to Python and Jupyter](https://gist.github.com/kenjyco/69eeb503125035f21a9d)
# - [Github collection of learning Python notebooks](https://github.com/jerry-git/learn-python3)
# - [Jupyter notebooks trainings from Jupyter](https://jupyter.org/try)

# %% [markdown]
# ### Python comments
#
# A hash character tells Python that anything after that point can be ignored and is just a 'comment' from the programmer. This can be the full line:

# %%
# This is our first python command, a comment. You can see python blocks have a gray background and the text gets colored green for comments

# %% [markdown]
# ### Python Strings

# %%
# Now lets make a string of dna bases, enclosed in either single or double quotes, which we'll assign to a variable called 'string_of_bases'
string_of_bases = 'ACGTACGT'
print(string_of_bases)

# %%
# String variables don't have to be a string of nucleotides, python strings can be anything
anything_string = 'this_IS_A StRiNg also 234234234234234'
print(anything_string)

# %%
# we've been using the 'print' function already. This function tells python to print out the contents of variable, which follows the cell. If the variable 
# doesn't exist Python will tell us that, spitting out a 'xxx' is not defined error.
print(a_variable_I_havent_made)

# %% [markdown]
# ### Numbers
#
# Python has both integer (0, 1, 2, 3, 4, -9967, etc) and floating point numbers (0.1, 0.664, 1e+45). We define these variables without quotes:

# %%
hours_left_today = 12
assignment_time = 13
chance_of_success = hours_left_today - assignment_time

print(chance_of_success)

# %% [markdown]
# ## Lots more to explore
#
# - Take a look at the tutorial in the same

# %% [markdown]
# ## YOUR ASSIGNMENT
#
# - Download the accompanying tutorial, take a look throughout
# - Download this notebook, run it in your Jupyter installation
# - Use this last cell to output the results of 2 + 2

# %%
## create a command that prints the results of 2 + 2
